# %% [markdown]
# # 9. History-Aware Retrieval
#
# This notebook makes retrieval aware of conversation context so follow-up questions work better.
#
# What to look for:
# - how the current question depends on chat history
# - why query rewriting can improve retrieval
# - how the retriever becomes more useful in multi-turn chats
