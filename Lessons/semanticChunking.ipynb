# %%
from langchain_openai import OpenAIEmbeddings
from langchain_experimental.text_splitter import SemanticChunker
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_20920\4189179044.py:2: DeprecationWarning: `langchain-experimental` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-experimental/issues/87 for details.
#   from langchain_experimental.text_splitter import SemanticChunker
